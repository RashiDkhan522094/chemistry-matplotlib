# %% [markdown]
# # 📊 Data Visualization with Python: Exploring NumPy, Pandas & Matplotlib
# **Author:** M. Rashid Khan | **Year:** 2025
# ---

# %% [markdown]
# ## 1. 📦 Importing Required Libraries

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_excel("Alloys.xlsx")

# %%
data.head()
# Out:
#                                                Alloy  \
# 0   ACI-ASTM CA15 (SCS1,J91150) Cast Stainless Steel
# 1       ACI-ASTM CA15M (J91151) Cast Stainless Steel
# 2     ACI-ASTM CA28MWV (J91422) Cast Stainless Steel
# 3  ACI-ASTM CA40 (SCS2A,J91153) Cast Stainless Steel
# 4       ACI-ASTM CA40F (J91154) Cast Stainless Steel
#
#    Tensile Strength: Ultimate (UTS) (psi)  Melting Completion (Liquidus)   Al  \
# 0                                   700.0                           1440  0.0
# 1                                   690.0                           1450  0.0
# 2                                  1080.0                           1470  0.0
# 3                                   910.0                           1440  0.0
# 4                                   770.0                           1430  0.0
#
#     As    B      C   Ca   Ce   Co  ...      S   Se     Si   Sn   Ta   Ti  \
# 0  0.0  0.0  0.075  0.0  0.0  0.0  ...  0.020  0.0  0.750  0.0  0.0  0.0
# ...

# %% [markdown]
# ### 📈 Line Graph

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.plot(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 📈 Line Graph

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.plot(data["C"],data["Zn"],linewidth=3,color="c" ,linestyle=":")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("C VS ZN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 📈 Line Graph

# %%
plt.Figure(figsize=(5,10), dpi=1000)
plt.plot(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=1,color="y" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("Rashid khan")
plt.grid(which='major', axis='both')
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.errorbar(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="k" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 🔵 Scatter Plot

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.scatter(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="r" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.step(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="c" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.loglog(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.semilogx(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="b" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.fill_betweenx(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="y" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.fill_between(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 📊 Bar Graph

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.bar(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 📊 Bar Graph

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.barh(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.stackplot(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="c" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.fill(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="b" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.cohere(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="y" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.csd(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="k" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.xcorr(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.hexbin(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3, color="r" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.quiver(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3, color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 📊 Bar Graph

# %%
plt.Figure(figsize=(5,10), dpi=100)
plt.bar(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=3 ,linestyle="--",align="center")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %%
fig = plt.figure(figsize=(5, 10), dpi=100, facecolor="blue", edgecolor="red", linewidth=10, frameon=False)
plt.stackplot(data["Tensile Strength: Ultimate (UTS) (psi)"], data["Melting Completion (Liquidus)"],linewidth=3,colors=["c"])
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("RASHID KHAN")
plt.grid(visible=True)
plt.show()

# %% [markdown]
# ### 📈 Line Graph

# %%
fig = plt.figure(figsize=(10, 10), dpi=100, facecolor="blue", edgecolor="red", linewidth=10, frameon=False)
plt.subplot(2,2,1)
plt.plot(data["Tensile Strength: Ultimate (UTS) (psi)"], data["Melting Completion (Liquidus)"],linewidth=3,color="r")
plt.subplot(2,2,2)
plt.scatter(data["Tensile Strength: Ultimate (UTS) (psi)"], data["Melting Completion (Liquidus)"],linewidth=3,color="g")
plt.subplot(2,2,3)
plt.bar(data["Tensile Strength: Ultimate (UTS) (psi)"], data["Melting Completion (Liquidus)"],linewidth=3,color="k")
plt.subplot(2,2,4)
plt.pie( data["Melting Completion (Liquidus)"])
plt.show()

# %% [markdown]
# ### 📈 Line Graph

# %%
fig = plt.figure(figsize=(10, 10), dpi=100, facecolor="blue", edgecolor="red", linewidth=10, frameon=False)
plt.subplot(2,2,1)
x=[1,2,3,4,11]
y=[5,6,7,8,9]
plt.subplot(2,2,1)
plt.plot(x , y ,color="g")

x1=[132,332,34234,2321]
plt.subplot(2,2,2)
plt.pie(x1)

x2=[12,323,12,23]
y1=[31231231,34123123,2423422,312312]
plt.subplot(2,2,3)
plt.bar(x2 ,y1, color="b")
x3=['RASHID' ,'AKIF' ,'uzair']
y2=['ahmad' ,'danyal', 'saif']
plt.subplot(2,2,4)
plt.scatter(x3 , y2 , color='k')

# %% [markdown]
# ### 📈 Line Graph

# %%
plt.Figure(figsize=(5,5), dpi=100)
plt.plot(data["Tensile Strength: Ultimate (UTS) (psi)"],data["Melting Completion (Liquidus)"],linewidth=1,color="g" ,linestyle="--")
plt.xlabel("Tensile Strength: Ultimate (UTS) (psi)")
plt.ylabel("Melting Completion (Liquidus)")
plt.title("T VS M")
plt.grid(visible=True)
plt.subplot(2,2,1)

plt.Figure(figsize=(5,10), dpi=100)
plt.plot(data["C"],data["Zn"],linewidth=3,color="c" ,linestyle=":")
plt.xlabel("C")
plt.ylabel("Zn")

plt.title("C VS ZN")
plt.grid(visible=True)
plt.subplot(2,2,2)

plt.Figure(figsize=(5,10), dpi=1000)
plt.plot(data["Co"],data["S"],linewidth=1,color="y" ,linestyle="--")
plt.xlabel("Co")
plt.ylabel("S")
plt.title("Co VS S")

plt.grid(which='major', axis='both')
plt.subplot(2,2,3)

plt.Figure(figsize=(5,10), dpi=100)
plt.errorbar(data["Co"],data["S"],linewidth=1,color="y" ,linestyle="--")
plt.xlabel("Co")
plt.ylabel("S")
plt.title("Co VS S")

plt.grid(visible=True)
plt.subplot(2,2,4)
plt.savefig("RAHID KHAN123.jpg")

# %% [markdown]
# ## ✅ Conclusion
# This notebook demonstrates how to visualize and explore data using NumPy, Pandas, and Matplotlib — essential skills for any aspiring data scientist or researcher.
#
# 🔗 Share your thoughts or improvements on LinkedIn!
#
# #Python #DataScience #NUST #Visualization #Matplotlib #Pandas
